# %% [markdown]
# # **Machine Learning in Python: Performing Principal Component Analysis (PCA)**
#
# Abdullah Al Shamim
#
# Github, https://github.com/PrinceShamim022/Fisheries_DataAnalysis_Projects/tree/main/Clam </i>
#
# In this Jupyter notebook, we will be performing Principal Component Analysis (PCA) using the clam data set as an example.

# %% [markdown]
# ---

# %% [markdown]
# *italicized text*## **1. Clam data set**

# %% [markdown]
# ### Load library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load dataset

# %%
# !git clone https://github.com/PrinceShamim022/Fisheries_DataAnalysis_Projects.git
# Out:
# fatal: destination path 'Fisheries_DataAnalysis_Projects' already exists and is not an empty directory.

# %%
df = pd.read_csv('/content/Fisheries_DataAnalysis_Projects/Clam/clam.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of       SL..NO.     Month Color Deform  Trt     SL     SH     SW     LL     PL  \
# 0           1   January    A1    NaN    1  41.47  33.00  22.63   8.01  34.06
# 1           2   January    A2    NaN    1  39.85  31.55  21.40   9.94  31.82
# 2           3   January    A3    NaN    1  39.48  33.25  22.92   9.83  32.86
# 3           4   January    A4    NaN    1  41.09  35.11  22.71  10.52  34.16
# 4           5   January    A5    NaN    1  35.13  29.42  20.18   9.51  27.69
# ...       ...       ...   ...    ...  ...    ...    ...    ...    ...    ...
# 2288     2396  December    J1    NaN    6  32.78  25.62  16.03   6.57  23.86
# 2289     2397  December    K1    NaN    7  27.92  21.76  14.90   6.15  20.10
# 2290     2398  December    K2      D    7  31.44  26.66  16.67   7.43  23.89
# 2291     2399  December    K3    NaN    7  31.15  23.43  13.99   5.95  21.66
# 2292     2400  December    K4    NaN    7  30.50  24.70  14.01   5.75  20.05
#
#       ...     UL    LCT   LPAS    PW    AW   PVM    PS  CT..RIGHT.TEETH.  \
# 0     ...  32.25  24.30  24.41  7.83  4.47  7.29  7.68              5.18
# 1     ...  29.02  18.62  21.62  6.71  4.77  8.15  7.11              6.45
# 2     ...  29.87  17.27  22.61  6.17  5.01  6.76  8.26              7.38
# 3     ...  32.35  15.56  22.86  7.61  4.47  8.50  6.53              6.52
# 4     ...  28.06  15.21  18.84  7.51  4.42  7.22  7.00              6.00
# ...   ...    ...    ...    ...   ...   ...   ...   ...               ...
# 2288  ...  23.68  14.46  20.70  4.76  3.20  6.03  4.64              2.21
# 2289  ...  19.35  11.83  18.49  3.62  2.71  4.90  4.79              3.01
# 2290  ...  24.43  13.16  19.43  5.29  4.08  6.32  5.17              4.29
# 2291  ...  21.65  13.09  18.74  4.23  3.40  6.49  5.13              4.01
# 2292  ...  20.71  13.21  18.09  4.01  3.27  6.70  4.93              3.97
#
#       Total.wt  muscle.wt
# 0        24.50       5.72
# 1        22.37       4.60
# 2        22.22       4.09
# 3        24.40       4.17
# 4        20.03       2.87
# ...        ...        ...
# 2288     18.32       1.59
# 2289     14.52       1.26
# 2290     17.54       1.89
# 2291     17.53       1.22
# 2292     16.54       1.11
#
# [2293 rows x 21 columns]>

# %%
df.columns
# Out:
# Index(['SL..NO.', 'Month', 'Color', 'Deform', 'Trt', 'SL', 'SH', 'SW', 'LL',
#        'PL', 'AL', 'UL', 'LCT', 'LPAS', 'PW', 'AW', 'PVM', 'PS',
#        'CT..RIGHT.TEETH.', 'Total.wt', 'muscle.wt'],
#       dtype='object')

# %%
features = ['SL', 'SH', 'SW', 'LL',
       'PL', 'AL', 'UL', 'LCT', 'LPAS', 'PW', 'AW', 'PVM', 'PS',
       'CT..RIGHT.TEETH.', 'Total.wt', 'muscle.wt']

# %%
df = df.dropna(subset = features)

# %%
data = df[features].copy()

# %%
data
# Out:
#          SL     SH     SW     LL     PL     AL     UL    LCT   LPAS    PW  \
# 0     41.47  33.00  22.63   8.01  34.06  24.97  32.25  24.30  24.41  7.83
# 1     39.85  31.55  21.40   9.94  31.82  24.01  29.02  18.62  21.62  6.71
# 2     39.48  33.25  22.92   9.83  32.86  25.63  29.87  17.27  22.61  6.17
# 3     41.09  35.11  22.71  10.52  34.16  26.59  32.35  15.56  22.86  7.61
# 4     35.13  29.42  20.18   9.51  27.69  22.84  28.06  15.21  18.84  7.51
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...   ...
# 2288  32.78  25.62  16.03   6.57  23.86  17.69  23.68  14.46  20.70  4.76
# 2289  27.92  21.76  14.90   6.15  20.10  14.61  19.35  11.83  18.49  3.62
# 2290  31.44  26.66  16.67   7.43  23.89  17.60  24.43  13.16  19.43  5.29
# 2291  31.15  23.43  13.99   5.95  21.66  15.48  21.65  13.09  18.74  4.23
# 2292  30.50  24.70  14.01   5.75  20.05  15.09  20.71  13.21  18.09  4.01
#
#         AW   PVM    PS  CT..RIGHT.TEETH.  Total.wt  muscle.wt
# 0     4.47  7.29  7.68              5.18     24.50       5.72
# 1     4.77  8.15  7.11              6.45     22.37       4.60
# 2     5.01  6.76  8.26              7.38     22.22       4.09
# 3     4.47  8.50  6.53              6.52     24.40       4.17
# 4     4.42  7.22  7.00              6.00     20.03       2.87
# ...    ...   ...   ...               ...       ...        ...
# 2288  3.20  6.03  4.64              2.21     18.32       1.59
# 2289  2.71  4.90  4.79              3.01     14.52       1.26
# 2290  4.08  6.32  5.17              4.29     17.54       1.89
# 2291  3.40  6.49  5.13              4.01     17.53       1.22
# 2292  3.27  6.70  4.93              3.97     16.54       1.11
#
# [2293 rows x 16 columns]

# %% [markdown]
# ### Input features

# %%
print(data)
# Out:
#          SL     SH     SW     LL     PL     AL     UL    LCT   LPAS    PW  \
# 0     41.47  33.00  22.63   8.01  34.06  24.97  32.25  24.30  24.41  7.83
# 1     39.85  31.55  21.40   9.94  31.82  24.01  29.02  18.62  21.62  6.71
# 2     39.48  33.25  22.92   9.83  32.86  25.63  29.87  17.27  22.61  6.17
# 3     41.09  35.11  22.71  10.52  34.16  26.59  32.35  15.56  22.86  7.61
# 4     35.13  29.42  20.18   9.51  27.69  22.84  28.06  15.21  18.84  7.51
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...   ...
# 2288  32.78  25.62  16.03   6.57  23.86  17.69  23.68  14.46  20.70  4.76
# 2289  27.92  21.76  14.90   6.15  20.10  14.61  19.35  11.83  18.49  3.62
# 2290  31.44  26.66  16.67   7.43  23.89  17.60  24.43  13.16  19.43  5.29
# 2291  31.15  23.43  13.99   5.95  21.66  15.48  21.65  13.09  18.74  4.23
# 2292  30.50  24.70  14.01   5.75  20.05  15.09  20.71  13.21  18.09  4.01
#
#         AW   PVM    PS  CT..RIGHT.TEETH.  Total.wt  muscle.wt
# 0     4.47  7.29  7.68              5.18     24.50       5.72
# 1     4.77  8.15  7.11              6.45     22.37       4.60
# 2     5.01  6.76  8.26              7.38     22.22       4.09
# 3     4.47  8.50  6.53              6.52     24.40       4.17
# 4     4.42  7.22  7.00              6.00     20.03       2.87
# ...    ...   ...   ...               ...       ...        ...
# 2288  3.20  6.03  4.64              2.21     18.32       1.59
# 2289  2.71  4.90  4.79              3.01     14.52       1.26
# 2290  4.08  6.32  5.17              4.29     17.54       1.89
# 2291  3.40  6.49  5.13              4.01     17.53       1.22
# 2292  3.27  6.70  4.93              3.97     16.54       1.11
#
# [2293 rows x 16 columns]

# %% [markdown]
# ### Output features

# %%
print(df.Trt)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2288    6
# 2289    7
# 2290    7
# 2291    7
# 2292    7
# Name: Trt, Length: 2293, dtype: int64

# %% [markdown]
# ### Assigning Input (X) and Output (Y) variables
# Let's assign the 4 input variables to X and the output variable (class label) to Y

# %%
X = data
Y = df.Trt

# %%
X
# Out:
#          SL     SH     SW     LL     PL     AL     UL    LCT   LPAS    PW  \
# 0     41.47  33.00  22.63   8.01  34.06  24.97  32.25  24.30  24.41  7.83
# 1     39.85  31.55  21.40   9.94  31.82  24.01  29.02  18.62  21.62  6.71
# 2     39.48  33.25  22.92   9.83  32.86  25.63  29.87  17.27  22.61  6.17
# 3     41.09  35.11  22.71  10.52  34.16  26.59  32.35  15.56  22.86  7.61
# 4     35.13  29.42  20.18   9.51  27.69  22.84  28.06  15.21  18.84  7.51
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...   ...
# 2288  32.78  25.62  16.03   6.57  23.86  17.69  23.68  14.46  20.70  4.76
# 2289  27.92  21.76  14.90   6.15  20.10  14.61  19.35  11.83  18.49  3.62
# 2290  31.44  26.66  16.67   7.43  23.89  17.60  24.43  13.16  19.43  5.29
# 2291  31.15  23.43  13.99   5.95  21.66  15.48  21.65  13.09  18.74  4.23
# 2292  30.50  24.70  14.01   5.75  20.05  15.09  20.71  13.21  18.09  4.01
#
#         AW   PVM    PS  CT..RIGHT.TEETH.  Total.wt  muscle.wt
# 0     4.47  7.29  7.68              5.18     24.50       5.72
# 1     4.77  8.15  7.11              6.45     22.37       4.60
# 2     5.01  6.76  8.26              7.38     22.22       4.09
# 3     4.47  8.50  6.53              6.52     24.40       4.17
# 4     4.42  7.22  7.00              6.00     20.03       2.87
# ...    ...   ...   ...               ...       ...        ...
# 2288  3.20  6.03  4.64              2.21     18.32       1.59
# 2289  2.71  4.90  4.79              3.01     14.52       1.26
# 2290  4.08  6.32  5.17              4.29     17.54       1.89
# 2291  3.40  6.49  5.13              4.01     17.53       1.22
# 2292  3.27  6.70  4.93              3.97     16.54       1.11
#
# [2293 rows x 16 columns]

# %%
Y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2288    6
# 2289    7
# 2290    7
# 2291    7
# 2292    7
# Name: Trt, Length: 2293, dtype: int64

# %% [markdown]
# ### Let's examine the data dimension

# %%
X.shape
# Out:
# (2293, 16)

# %%
Y.shape
# Out:
# (2293,)

# %% [markdown]
# ---

# %% [markdown]
# ## **2. PCA analysis**

# %% [markdown]
# ### 2.1. Load library

# %%
from sklearn.preprocessing import scale # Data scaling
from sklearn import decomposition #PCA

# %% [markdown]
# ### 2.2. Data scaling

# %%
X = scale(X)

# %% [markdown]
# ### 2.3. Perform PCA analysis

# %% [markdown]
# Here we define the number of PC to use as 3

# %%
pca = decomposition.PCA(n_components=7)
pca.fit(X)
# Out:
# PCA(n_components=7)

# %% [markdown]
# #### 2.4. Compute and retrieve the **scores** values

# %%
scores = pca.transform(X)

# %%
scores_df = pd.DataFrame(scores, columns=['PC1', 'PC2', 'PC3','PC4', 'PC5', 'PC6', 'PC7'])   # make dataframe for scores
scores_df
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7
# 0    -3.608297  0.027792  2.055425 -0.559572 -1.151521  0.449256  0.934942
# 1    -2.321065 -1.319160  1.602370 -0.170173 -0.281348 -0.164782 -0.261823
# 2    -2.634265 -2.277664  1.112976 -0.508562 -1.079184  0.819189  0.056572
# 3    -3.167489 -1.088887  0.956553 -0.345439  0.308728 -0.381656 -0.078490
# 4    -0.394343 -1.617757  0.717206  0.607583 -0.657228 -0.018757 -0.594896
# ...        ...       ...       ...       ...       ...       ...       ...
# 2288  3.673399  1.490560 -0.348394  0.007197 -0.537082 -0.389799  0.239142
# 2289  5.999144  0.452085 -0.088217 -0.399148 -0.845529  0.019423 -0.209234
# 2290  2.925657 -0.261820  0.167502  0.600797 -0.269199 -0.071712 -0.186178
# 2291  4.479540 -0.314959 -0.267683  0.151667 -0.510798 -0.651645  0.085011
# 2292  4.834987 -0.306181 -0.289757  0.114884 -0.364848 -0.870893 -0.061592
#
# [2293 rows x 7 columns]

# %%
Y_label = []

for i in Y:
  if i == 1:
    Y_label.append('Green')
  elif i == 2:
    Y_label.append('Blue')
  elif i == 3:
    Y_label.append('Orange')
  elif i == 4:
    Y_label.append('Black')
  elif i == 5:
    Y_label.append('Purple')
  elif i == 6:
    Y_label.append('Red')
  else:
    Y_label.append('Violet')

Trt = pd.DataFrame(Y_label, columns=['Trt'])

# %%
df_scores = pd.concat([scores_df, Trt], axis=1)  # add scores column with species

# %% [markdown]
# #### 2.5. Retrieve the **loadings** values

# %%
loadings = pca.components_.T
df_loadings = pd.DataFrame(loadings, columns=['PC1', 'PC2', 'PC3','PC4', 'PC5', 'PC6', 'PC7'], index=data.columns)
df_loadings
# Out:
#                        PC1       PC2       PC3       PC4       PC5       PC6  \
# SL               -0.275058  0.036524 -0.114732 -0.076230  0.072438 -0.026976
# SH               -0.275626  0.037361 -0.085574 -0.095969  0.062606  0.004256
# SW               -0.269675  0.039620 -0.074487 -0.098580  0.136915 -0.021656
# LL               -0.252634  0.143511 -0.014052 -0.075348  0.059656  0.196969
# PL               -0.271299 -0.041332 -0.100876 -0.127307  0.167420  0.040322
# AL               -0.268009  0.041457 -0.028908 -0.014138  0.017579  0.015102
# UL               -0.273346  0.083997 -0.092721 -0.097326  0.066027  0.031293
# LCT              -0.255402  0.178610 -0.065008 -0.042099  0.051907  0.206377
# LPAS             -0.249839  0.260535 -0.162631 -0.178339 -0.321992  0.182647
# PW               -0.256075 -0.021447  0.077369  0.429977 -0.071481  0.088781
# AW               -0.239290 -0.094570  0.107846  0.787212  0.033660  0.170726
# PVM              -0.249117 -0.084078 -0.013906  0.083511  0.149835 -0.876046
# PS               -0.231875 -0.371577  0.011781 -0.082867 -0.833409 -0.112589
# CT..RIGHT.TEETH. -0.142866 -0.826193  0.024677 -0.208307  0.306632  0.247229
# Total.wt         -0.260722  0.106947 -0.127408 -0.063543  0.108410 -0.054025
# muscle.wt        -0.192301  0.127543  0.942706 -0.210413  0.020452 -0.000182
#
#                        PC7
# SL                0.199764
# SH                0.060191
# SW                0.008532
# LL               -0.804718
# PL                0.108288
# AL                0.028016
# UL                0.071626
# LCT              -0.103139
# LPAS              0.050160
# PW               -0.024091
# AW                0.071302
# PVM              -0.217604
# PS               -0.016412
# CT..RIGHT.TEETH. -0.034566
# Total.wt          0.463409
# muscle.wt         0.093838

# %% [markdown]
# #### 2.6. **Explained variance** for each PC

# %%
explained_variance = pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.7888531 , 0.06206347, 0.03509975, 0.02195   , 0.01506714,
#        0.01469385, 0.01285586])

# %% [markdown]
# ## **3. Scree Plot**

# %% [markdown]
# ### 3.1. Import library

# %%
import numpy as np
import plotly.express as px

# %% [markdown]
# ### 3.2. Preparing explained variance and cumulative variance

# %% [markdown]
# #### 3.2.1. Preparing the explained variance data

# %%
explained_variance
# Out:
# array([0.7888531 , 0.06206347, 0.03509975, 0.02195   , 0.01506714,
#        0.01469385, 0.01285586])

# %%
explained_variance = np.insert(explained_variance, 0, 0)

# %% [markdown]
# #### 3.2.2. Preparing the cumulative variance data

# %%
cumulative_variance = np.cumsum(np.round(explained_variance, decimals=3))

# %% [markdown]
# #### 3.2.3. Combining the dataframe

# %%
pc_df = pd.DataFrame(['','PC1', 'PC2', 'PC3','PC4', 'PC5', 'PC6', 'PC7'], columns=['PC'])
explained_variance_df = pd.DataFrame(explained_variance, columns=['Explained Variance'])
cumulative_variance_df = pd.DataFrame(cumulative_variance, columns=['Cumulative Variance'])

# %%
df_explained_variance = pd.concat([pc_df, explained_variance_df, cumulative_variance_df], axis=1)  # create dataframe by adding pc_df, explained_variance_df, cumulative_variance_df
df_explained_variance
# Out:
#     PC  Explained Variance  Cumulative Variance
# 0                 0.000000                0.000
# 1  PC1            0.788853                0.789
# 2  PC2            0.062063                0.851
# 3  PC3            0.035100                0.886
# 4  PC4            0.021950                0.908
# 5  PC5            0.015067                0.923
# 6  PC6            0.014694                0.938
# 7  PC7            0.012856                0.951

# %% [markdown]
# #### 3.2.4. Making the scree plot

# %% [markdown]
# ##### 3.2.4.1. Explained Variance

# %%
# https://plotly.com/python/bar-charts/

fig = px.bar(df_explained_variance,
             x='PC', y='Explained Variance',
             text='Explained Variance',
             width=800)

fig.update_traces(texttemplate='%{text:.3f}', textposition='outside')  # fig customization
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e8c486a8-0dc1-41a4-8d50-ee867ca99d8d" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8c486a8-0dc1-41a4-8d50-ee867ca99d8d")) {                    Plotly.newPlot(                        "e8c486a8-0dc1-41a4-8d50-ee867ca99d8d",                        [{"alignmentgroup":"True","hovertemplate":"PC=%{x}\u003cbr\u003eExplained Variance=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[0.0,0.7888530953954088,0.06206347064346625,0.03509975025933542,0.021949995421651044,0.015067138108954449,0.01469384969266416,0.01285586200913956],"textposition":"outside","x":["","PC1","PC2","PC3","PC4","PC5","PC6","PC7"],"xaxis":"x","y":[0.0,0.7888530953954088,0.06206347064346625,0.03509975025933542,0.021949995421651044,0.015067138108954449,0.01469384969266416,0.01285586200913956],"yaxis":"y","type":"bar","texttemplate":"%{text:.3f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scat ...

# %% [markdown]
# ##### 3.2.4.2. Explained Variance + Cumulative Variance

# %%
# https://plotly.com/python/creating-and-updating-figures/
# create 2 plots in a graph (bar+scatter)

import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=df_explained_variance['PC'],
        y=df_explained_variance['Cumulative Variance'],
        marker=dict(size=15, color="LightSeaGreen")
    ))

fig.add_trace(
    go.Bar(
        x=df_explained_variance['PC'],
        y=df_explained_variance['Explained Variance'],
        marker=dict(color="RoyalBlue")
    ))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f21e4803-2ed8-4e22-9ea3-00a3f2676e35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f21e4803-2ed8-4e22-9ea3-00a3f2676e35")) {                    Plotly.newPlot(                        "f21e4803-2ed8-4e22-9ea3-00a3f2676e35",                        [{"marker":{"color":"LightSeaGreen","size":15},"x":["","PC1","PC2","PC3","PC4","PC5","PC6","PC7"],"y":[0.0,0.789,0.851,0.886,0.908,0.923,0.9380000000000001,0.9510000000000001],"type":"scatter"},{"marker":{"color":"RoyalBlue"},"x":["","PC1","PC2","PC3","PC4","PC5","PC6","PC7"],"y":[0.0,0.7888530953954088,0.06206347064346625,0.03509975025933542,0.021949995421651044,0.015067138108954449,0.01469384969266416,0.01285586200913956],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{ ...

# %% [markdown]
# ##### 3.2.4.3. Explained Variance + Cumulative Variance (Separate Plot)

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=1, cols=2)

fig.add_trace(
    go.Scatter(
        x=df_explained_variance['PC'],
        y=df_explained_variance['Cumulative Variance'],
        marker=dict(size=15, color="LightSeaGreen")
    ), row=1, col=1
    )

fig.add_trace(
    go.Bar(
        x=df_explained_variance['PC'],
        y=df_explained_variance['Explained Variance'],
        marker=dict(color="RoyalBlue"),
    ), row=1, col=2
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ac5b0265-d9be-4d4b-9143-77d67edc94c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac5b0265-d9be-4d4b-9143-77d67edc94c0")) {                    Plotly.newPlot(                        "ac5b0265-d9be-4d4b-9143-77d67edc94c0",                        [{"marker":{"color":"LightSeaGreen","size":15},"x":["","PC1","PC2","PC3","PC4","PC5","PC6","PC7"],"y":[0.0,0.789,0.851,0.886,0.908,0.923,0.9380000000000001,0.9510000000000001],"type":"scatter","xaxis":"x","yaxis":"y"},{"marker":{"color":"RoyalBlue"},"x":["","PC1","PC2","PC3","PC4","PC5","PC6","PC7"],"y":[0.0,0.7888530953954088,0.06206347064346625,0.03509975025933542,0.021949995421651044,0.015067138108954449,0.01469384969266416,0.01285586200913956],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size": ...

# %% [markdown]
